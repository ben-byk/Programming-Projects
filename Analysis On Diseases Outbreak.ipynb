# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
cm = pd.read_excel("Class work.xlsx")
cm.head().T
# Out:
#                                               0          1            2  \
# Country                                   Italy     France       Turkey
# Year                                       2013       2002         2015
# Disease Name                            Malaria      Ebola     COVID-19
# Disease Category                    Respiratory  Parasitic      Genetic
# Prevalence Rate (%)                        0.95      12.46         0.91
# Incidence Rate (%)                         1.55       8.63         2.35
# Mortality Rate (%)                         8.42       8.75         6.22
# Age Group                                  0-18        61+        36-60
# Gender                                     Male       Male         Male
# Population Affected                      471007     634318       154878
# Healthcare Access (%)                     57.74      89.21        56.41
# Doctors per 1000                           3.34       1.33         4.07
# ...

# %%
#Explaining the data
film= cm.describe()
film
# Out:
#               Year  Prevalence Rate (%)  Incidence Rate (%)  \
# count  1500.000000          1500.000000         1500.000000
# mean   2011.789333            10.272320            7.519700
# std       7.210984             5.726204            4.275134
# min    2000.000000             0.110000            0.110000
# 25%    2006.000000             5.447500            3.877500
# 50%    2011.500000            10.550000            7.475000
# 75%    2018.000000            15.130000           11.182500
# max    2024.000000            20.000000           15.000000
#
#        Mortality Rate (%)  Population Affected  Healthcare Access (%)  \
# count         1500.000000          1500.000000             1500.00000
# mean             5.032247        500031.944667               74.97818
# std              2.838037        288853.513742               14.72358
# min              0.100000          3062.000000               50.00000
# 25%              2.550000        245990.000000               61.99750
# ...

# %%
book = cm.describe(include=['object'])
book
# Out:
#         Country Disease Name Disease Category Age Group Gender Treatment Type  \
# count      1500         1500             1500      1500   1500           1500
# unique       20           20               11         4      3              4
# top     Nigeria       Rabies       Autoimmune     36-60   Male    Vaccination
# freq         92           90              157       415    541            396
#
#        Availability of Vaccines/Treatment
# count                                1500
# unique                                  2
# top                                    No
# freq                                  772

# %%
# Histogram for Prevalence Rate
sns.histplot(cm["Prevalence Rate (%)"], kde=True, color="blue", bins=11)
plt.title("Distribution of the Prevalence Rate")
plt.xlabel("Prevalence Rate")
plt.ylabel("Frequency")
plt.show()

# %%
# Histogram for Mortality Rate
sns.histplot(cm["Mortality Rate (%)"], kde=True, color="blue", bins=10)
plt.title("Distribution of Mortality Rate")
plt.xlabel("Mortality Rate")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#Bar chart of healthcare acesss
plt.figure(figsize=(8, 6))
sns.barplot(y="Country", x="Healthcare Access (%)", data = cm)
plt.title("Distribution Of Healthcare Accessibility")
plt.xlabel("Healthcare Access (%)")
plt.ylabel("Country")
plt.show()

# %%
#Insights on Diseases prevelance rate
top5 = cm.sort_values(by='Prevalence Rate (%)', ascending=False).head(5)
top5
# Out:
#            Country  Year Disease Name Disease Category  Prevalence Rate (%)  \
# 1111        Mexico  2020     Diabetes        Bacterial                20.00
# 323          Japan  2023         Zika          Chronic                20.00
# 1379       Germany  2007      Measles          Genetic                19.98
# 692      Australia  2005    Hepatitis          Chronic                19.98
# 586   South Africa  2022       Asthma        Bacterial                19.97
#
#       Incidence Rate (%)  Mortality Rate (%) Age Group  Gender  \
# 1111                8.40                8.41      0-18  Female
# 323                12.67                2.03     36-60   Other
# 1379                4.84                8.76       61+    Male
# 692                 9.56                2.22     36-60    Male
# 586                 2.34                0.32     19-35   Other
#
#       Population Affected  ...  Hospital Beds per 1000  Treatment Type  \
# ...

# %%
cm_sorted = cm.sort_values(by='Doctors per 1000', ascending=True)
top10 = cm_sorted.head(10)
top10 = top10[['Country', 'Doctors per 1000']]
top10
# Out:
#         Country  Doctors per 1000
# 1156     Turkey              0.50
# 1188      India              0.50
# 689      Turkey              0.51
# 222      Brazil              0.51
# 845      Brazil              0.51
# 233   Argentina              0.51
# 731       Japan              0.51
# 147   Australia              0.53
# 1441    Nigeria              0.53
# 486      Brazil              0.53

# %%
# The top ten countries which require investment in the healthcare sector are as listed above.

# %%
df_sorted = df.sort_values(by='Hospital Beds per 1000', ascending=True)
top_10_worst = df_sorted.head(10)
top_10_worst = top_10_worst[['Country', 'Hospital Beds per 1000']]
top_10_worst
# Out:
#         Country  Hospital Beds per 1000
# 1083     Russia                    0.50
# 1394      Japan                    0.50
# 1401  Argentina                    0.50
# 1000     Canada                    0.51
# 202      Mexico                    0.52
# 658   Argentina                    0.52
# 286      Russia                    0.52
# 990   Argentina                    0.54
# 353      France                    0.55
# 46       Brazil                    0.55

# %%
#  top ten countries that requires investment in the healthcare sector .

# %%
sns.scatterplot(data=cm, x='Education Index', y='Per Capita Income (USD)')
plt.title("Scatter Plot: Education Index vs  Per Capita Income (USD)")
plt.xlabel("Education Index")
plt.ylabel("Per Capita Income (USD)")
plt.show()

sns.scatterplot(data=cm, x='Education Index', y='Prevalence Rate (%)')
plt.title("Scatter Plot: Education Index vs Prevalence Rate (%)")
plt.xlabel("Education Index")
plt.ylabel("Prevalence Rate (%)")
plt.show()

sns.scatterplot(data=cm, x='Prevalence Rate (%)', y='Per Capita Income (USD)')
plt.title("Scatter Plot: Prevalence Rate (%) vs Per Capita Income (USD)")
plt.xlabel("Prevalence Rate (%)")
plt.ylabel("Per Capita Income (USD)")
plt.show()

# %%
#The Graphs above shows the correlation between The th columns using a scatterplot
#There are no correlation between them because the dots are radomnly plotted on the graph so cant prove it

# %%
cm_sorted = cm.sort_values(by='DALYs', ascending=False)
top10 = cm_sorted.head(10)
top10 = top10[['Country', 'DALYs']]
top10
# Out:
#         Country  DALYs
# 394      Russia   4999
# 23        Japan   4994
# 201       Italy   4989
# 1144  Indonesia   4988
# 1305     Canada   4986
# 670      Russia   4984
# 634       China   4979
# 657     Germany   4978
# 465      Russia   4976
# 277      Brazil   4973

# %%
#According to the information above, these are the top ten countries with the highest disease burden, beginning from the worst

# %%
#To curb the DALYs rate in the countries above, there must be the promotion of vaccination,
#There should be availability of treatment, more doctors and infrastructure to handle the patients as well as regular education.

# %%
cm_sorted = cm.sort_values(by='Recovery Rate (%)', ascending=False)
top10 = cm_sorted
top10 = top10[['Recovery Rate (%)','Doctors per 1000']]
top10
# Out:
#       Recovery Rate (%)  Doctors per 1000
# 1135              98.96              1.17
# 821               98.95              1.12
# 669               98.94              2.27
# 246               98.89              0.64
# 1407              98.89              2.24
# ...                 ...               ...
# 418               50.23              2.25
# 1099              50.21              4.82
# 811               50.11              2.95
# 4                 50.06              4.61
# 1197              50.06              4.64
#
# [1500 rows x 2 columns]

# %%
cm_sorted = cm.sort_values(by='Recovery Rate (%)', ascending=False)
top10 = cm_sorted
pot = top10[['Recovery Rate (%)','Country']]
pot
# Out:
#       Recovery Rate (%)       Country
# 1135              98.96         India
# 821               98.95       Nigeria
# 669               98.94        Turkey
# 246               98.89        Turkey
# 1407              98.89  Saudi Arabia
# ...                 ...           ...
# 418               50.23        France
# 1099              50.21        Russia
# 811               50.11     Argentina
# 4                 50.06         Italy
# 1197              50.06         China
#
# [1500 rows x 2 columns]

# %%
#Bar Chart comparing healthcare access accross the countries
plt.figure(figsize=(8, 6))
sns.barplot(y="Country", x="Recovery Rate (%)", data = top10 , palette = "plasma")
plt.title("The Relationship Between Countries and the Recovery Rate")
plt.xlabel("Recovery Rate (%)")
plt.ylabel("Country")
plt.show()

# %%
#This graph shows the relationship between countries with the best medical conditions, and the recovery rate

# %%
#ATI CLIFFORD 11146497
#BRANDFORD METTLE 11259497
